# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from welly import Project 
from welly import Well

# %%
p = Project.from_las("C:\\Users\\danie\\Documents\\Force_Hackathon\\GEOLINK_Lithology and wells NORTH SEA\\*.las")
# Out:
# 223it [03:20,  1.24s/it]

# %%
alias={
    'Gamma':['GR','SGR','CGR'],
    'D_Resistivity':['RDEP'],
    'Density':['RHOB'],
    'M_Resistivity':['RMED'],
    'C_sonic': ['DTC','DT'],
    'Caliper':['CALI','DCAL'],
    'Neutron':['NPHI'],
    'Density_correction':['DRHO'],
    'S_Resistivity':['RSHA'],
    'SP':['SP']
}

keys=[]
for k in alias.keys():
    keys.append(k)

html1=p.curve_table_html()
html = p.curve_table_html(keys=keys,alias=alias)

# %%
from IPython.display import HTML
HTML(html1)
# Out:
# <table><tr><th>Idx</th><th>UWI</th><th>Data</th><th>Quality</th><th>LITHOLOGY_GEOLINK</th><th>GR</th><th>RDEP</th><th>RHOB</th><th>RMED</th><th>DTC</th><th>CALI</th><th>NPHI</th><th>DRHO</th><th>RSHA</th><th>SP</th><th>BS</th><th>PEF</th><th>DTE</th><th>ROP</th><th>DTS</th><th>DCAL</th><th>RMIC</th><th>THOR</th><th>URAN</th><th>SGR</th><th>RXO</th><th>MUDWEIGHT</th><th>DT</th><th>RHOM</th><th>CGR</th><th>TGAS</th></tr><tr><td></td><td></td><td></td><td>%</td><td>223/223&nbsp;wells</td><td>205/223&nbsp;wells</td><td>204/223&nbsp;wells</td><td>200/223&nbsp;wells</td><td>200/223&nbsp;wells</td><td>198/223&nbsp;wells</td><td>196/223&nbsp;wells</td><td>188/223&nbsp;wells</td><td>187/223&nbsp;wells</td><td>154/223&nbsp;wells</td><td>147/223&nbsp;wells</td><td>106/223&nbsp;wells</td><td>91/223&nbsp;wells</td><td>59/223&nbsp;wells</td><td>53/223&nbsp;wells</td><td>49/223&nbsp;wells</td><td>35/223&nbsp;wells</td><td>35/223&nbsp;wells</td><td>34/223&nbsp;wells</td><td>34/223&nbsp;wells</td><td
# ...

# %%
HTML(html)
# Out:
# <table><tr><th>Idx</th><th>UWI</th><th>Data</th><th>Quality</th><th>Gamma*</th><th>D_Resistivity*</th><th>Density*</th><th>M_Resistivity*</th><th>C_sonic*</th><th>Caliper*</th><th>Neutron*</th><th>Density_correction*</th><th>S_Resistivity*</th><th>SP*</th></tr><tr><td></td><td></td><td></td><td>%</td><td>205/223&nbsp;wells</td><td>204/223&nbsp;wells</td><td>200/223&nbsp;wells</td><td>200/223&nbsp;wells</td><td>198/223&nbsp;wells</td><td>197/223&nbsp;wells</td><td>188/223&nbsp;wells</td><td>187/223&nbsp;wells</td><td>154/223&nbsp;wells</td><td>147/223&nbsp;wells</td></tr><td>0</td><td><span style="font-weight:bold;">15/9-12</span></td><td>10/13&nbsp;curves</td><td>0</td><td style="background-color:#CCEECC; line-height:80%; padding:5px 4px 2px 4px;">GR<div title="0" style="font-size:80%; float:right; cursor: default; padding:4px 0px 4px 6px; color:#FF3333;"></div><br /><span style="font-size:70%; color:#33AA33">44.66 gAPI</span></td><td style="background-color:#CCEECC; line-height:80%;
# ...

# %%
p_sub= Project.from_las("C:\\Users\\danie\\Documents\\Force_Hackathon\\GEOLINK_Lithology and wells NORTH SEA\\*.las",alias=alias,req=keys)
# Out:
# 0it [00:00, ?it/s]
# 1it [00:01,  1.45s/it]
# 2it [00:02,  1.38s/it]
# 3it [00:04,  1.38s/it]
# 4it [00:05,  1.37s/it]
# 5it [00:06,  1.36s/it]
# 6it [00:08,  1.54s/it]
# 7it [00:09,  1.24s/it]
# 8it [00:09,  1.03it/s]
# 9it [00:11,  1.11s/it]
# 10it [00:11,  1.13it/s]
# 11it [00:12,  1.17it/s]
# 12it [00:13,  1.02s/it]
# 13it [00:14,  1.03s/it]
# 14it [00:16,  1.16s/it]
# 15it [00:17,  1.21s/it]
# 16it [00:18,  1.20s/it]
# 17it [00:18,  1.13it/s]
# 18it [00:18,  1.47it/s]
# 19it [00:20,  1.17it/s]
# 20it [00:20,  1.52it/s]
# 21it [00:21,  1.21it/s]
# 22it [00:22,  1.21it/s]
# 23it [00:22,  1.56it/s]
# 24it [00:23,  1.40it/s]
# 25it [00:23,  1.62it/s]
# 26it [00:24,  1.50it/s]
# 27it [00:25,  1.47it/s]
# 28it [00:26,  1.52it/s]
# 29it [00:26,  1.35it/s]
# 30it [00:28,  1.15it/s]
# 31it [00:29,  1.04it/s]
# 32it [00:29,  1.34it/s]
# 33it [00:30,  1.34it/s]
# 34it [00:31,  1.23it/s]
# 35it [00:32,  1.06s/it]
# 36it [00:34,  1.22s/it]
# 37it [00:36,  1.32s/it]
# 38it [00:37,  1.24s/it]
# ...

# %%
p_su

# %%
dfs=[]

for w in p_sub:
    try:
        dfs.append(w.df())
        dfs[-1]['UWI']=w.uwi
        dfs[-1]['MD']=w.survey_basis()
    except:
        print("{}".format(w.uwi))
    

big_df=pd.concat(dfs,ignore_index=True)

# %%
big_df.info()
big_df.plot(x='CALI',y='MD')

# %%
big_df.to_csv('big_df.csv')

# %%
big_df['UWI'].unique()

# %%
print(len(big_df['UWI'].unique()))
